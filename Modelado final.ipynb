# %% [markdown]
# <p style = "font-size : 50px; color : 'blue' ; font-family : 'Arial'; text-align : center; background-color : #bedcfa; border-radius: 5px 5px;"><strong>Retrasos de vuelos </strong></p>

# %% [markdown]
# ## Parte 1 - Entender el problema
# El principal objetivo de negocio que se quiere abordar es predecir el retraso de vuelos comerciales, usando datos históricos de vuelos y de climatología.
#
# Para esto tenemos 2 conjuntos de datos: por un lado tenemos la información de vuelos y por el otro la información climatológica.
#
# El primer conjunto de datos contiene datos de retrasos de vuelos para el período de abril a octubre de 2013 especificando información sobre origen, destino, fecha, hora.
#
# Los datos meteorológicos representan observaciones de las estaciones meteorológicas del aeropuerto, que cubren el mismo período de tiempo de abril a octubre de 2013.

# %% [markdown]
# <center><img src="https://www.webintravel.com/wp-content/uploads/2020/05/den-belitsky-GettyImages-854673918-scaled.jpg" width="700"></center>

# %% [markdown]
# #### Importamos las librerias necesarias para el ejercicio

# %%
# !pip freeze
# Out:
# absl-py==0.15.0
# adjustText==0.8
# aenum==2.2.6
# aiohttp==3.8.6
# aiohttp-retry==2.8.3
# aiosignal==1.3.1
# alembic==1.12.1
# amqp==5.1.1
# aniso8601==9.0.1
# annotated-types==0.5.0
# ansi2html==1.8.0
# antlr4-python3-runtime==4.9.3
# anyio==3.6.2
# apache-libcloud==3.3.1
# appdirs==1.4.4
# apyori==1.1.2
# argon2-cffi==21.3.0
# argon2-cffi-bindings==21.2.0
# asgiref==3.3.1
# asttokens==2.0.8
# astunparse==1.6.3
# async-timeout==4.0.3
# asyncssh==2.14.0
# atomicwrites==1.4.0
# atpublic==4.0
# attrs==23.1.0
# auto-labeling-pipeline==0.1.15
# aws-cdk.assets==1.101.0
# aws-cdk.aws-apigateway==1.101.0
# aws-cdk.aws-applicationautoscaling==1.101.0
# aws-cdk.aws-autoscaling==1.101.0
# aws-cdk.aws-autoscaling-common==1.101.0
# aws-cdk.aws-autoscaling-hooktargets==1.101.0
# aws-cdk.aws-batch==1.101.0
# aws-cdk.aws-certificatemanager==1.101.0
# aws-cdk.aws-cloudformation==1.101.0
# aws-cdk.aws-cloudfront==1.101.0
# aws-cdk.aws-cloudwatch==1.101.0
# aws-cdk.aws-codebuild==1.101.0
# aws-cdk.aws-codecommit==1.101.0
# aws-cdk.aws-codeguruprofiler==1.101.0
# aws-cdk.aws-codepipeline==1.101.0
# aws-cdk.aws-cognito==1.101.0
# aws-cdk.aws-ec2==1.101.0
# aws-cdk.aws-ecr==1.101.0
# aws-cdk.aws-ecr-assets==1.101.0
# aws-cdk.aws-ecs==1.101.0
# aws-cdk.aws-efs==1.101.0
# aws-cdk.aws-elasticloadbalancing==1.101.0
# aws-cdk.aws-elasticloadbalancingv2==1.101.0
# aws-cdk.aws-events==1.101.0
# aws-cdk.aws-events-targets==1.101.0
# aws-cdk.aws-globalaccelerator==1.101.0
# aws-cdk.aws-glue==1.101.0
# aws-cdk.aws-iam==1.101.0
# aws-cdk.aws-kinesis==1.101.0
# aws-cdk.aws-kinesisfirehose==1.101.0
# aws-cdk.aws-kms==1.101.0
# aws-cdk.aws-lambda==1.101.0
# aws-cdk.aws-logs==1.101.0
# aws-cdk.aws-route53==1.101.0
# aws-cdk.aws-route53-targets==1.101.0
# aws-cdk.aws-s3==1.101.0
# aws-cdk.aws-s3-assets==1.101.0
# aws-cdk.aws-sam==1.101.0
# aws-cdk.aws-secretsmanager==1.101.0
# aws-cdk.aws-servicediscovery==1.101.0
# aws-cdk.aws-signer==1.101.0
# aws-cdk.aws-sns==1.101.0
# aws-cdk.aws-sns-subscriptions==1.101.0
# aws-cdk.aws-sqs==1.101.0
# aws-cdk.aws-ssm==1.101.0
# aws-cdk.aws-stepfunctions==1.101.0
# aws-cdk.cloud-assembly-schema==1.101.0
# aws-cdk.core==1.101.0
# aws-cdk.custom-resources==1.101.0
# aws-cdk.cx-api==1.101.0
# aws-cdk.region-info==1.101.0
# awscli==1.19.60
# Babel==2.10.3
# backcall==0.2.0
# beautifulsoup4==4.10.0
# beckett==0.8.0
# billiard==4.1.0
# bleach==5.0.1
# blinker==1.7.0
# blis==0.7.9
# bokeh==3.1.1
# boto3==1.17.78
# botocore==1.20.89
# branca==0.6.0
# cached-property==1.5.2
# cachetools==5.3.0
# catalogue==2.0.8
# category-encoders==2.6.0
# cattrs==1.9.0
# -e git+https://grupobancolombia.visualstudio.com/Vicepresidencia%20de%20Innovaci%C3%B3n%20y%20Transformaci%C3%B3n%20Digital/_git/vsas-aid-replica-poc.danihoyo@0fd1f286718ae3212a6f25e4edec56fdd182d954#egg=cdk&subdirectory=cicd\pipelines\functional_gluepopulator
# cdk-iam-floyd==0.285.0
# celery==5.3.4
# certifi==2023.7.22
# cffi==1.14.5
# chardet==4.0.0
# charset-normalizer==3.3.2
# click==8.1.7
# click-didyoumean==0.3.0
# click-plugins==1.1.1
# click-repl==0.3.0
# cligj==0.7.2
# cloudpickle==2.2.1
# colorama==0.4.6
# colour==0.1.5
# colourmap==1.1.16
# confection==0.0.4
# configobj==5.0.8
# conllu==4.4
# constructs==3.3.181
# contourpy==1.0.7
# coreapi==2.3.3
# coreschema==0.0.4
# coverage==5.5
# cryptography==41.0.5
# cupy-cuda113==10.6.0
# cycler==0.11.0
# cykhash==2.0.1
# cymem==2.0.7
# Cython==3.0.2
# dacite==1.8.1
# dash==2.14.1
# dash-core-components==2.0.0
# dash-html-components==2.0.0
# dash-table==5.0.0
# databricks-cli==0.18.0
# datazets==0.1.7
# debugpy==1.6.3
# decorator==5.1.1
# defusedxml==0.7.1
# dictdiffer==0.9.0
# diskcache==5.6.3
# distlib==0.3.1
# distro==1.8.0
# dj-database-url==0.5.0
# Django==3.1.7
# django-cors-headers==3.7.0
# django-filter==2.4.0
# django-polymorphic==3.0.0
# django-rest-polymorphic==0.1.9
# djangorestframework==3.12.2
# djangorestframework-csv==2.1.0
# djangorestframework-xml==2.0.0
# doccano==1.2.1
# docker==6.1.3
# docutils==0.15.2
# dpath==2.1.6
# drf-yasg==1.20.0
# dulwich==0.21.6
# dvc==3.27.0
# dvc-data==2.18.2
# dvc-http==2.30.2
# dvc-objects==1.0.1
# dvc-render==0.6.0
# dvc-studio-client==0.15.0
# dvc-task==0.3.0
# dython==0.7.3
# ecdsa==0.14.1
# en-core-web-sm @ https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.6.0/en_core_web_sm-3.6.0-py3-none-any.whl
# en-core-web-trf @ https://github.com/explosion/spacy-models/releases/download/en_core_web_trf-3.5.0/en_core_web_trf-3.5.0-py3-none-any.whl
# entrypoints==0.4
# environs==9.3.1
# es-core-news-sm @ https://github.com/explosion/spacy-models/releases/download/es_core_news_sm-3.6.0/es_core_news_sm-3.6.0-py3-none-any.whl
# et-xmlfile==1.0.1
# executing==1.1.1
# fastjsonschema==2.16.2
# fastrlock==0.8.1
# fbchat==1.9.7
# filelock==3.0.12
# findspark==2.0.1
# Fiona==1.9.4.post1
# Flask==3.0.0
# flask-restplus==0.13.0
# flask-restx==1.1.0
# flatbuffers==1.12
# flatten-dict==0.4.2
# flufl.lock==7.1.1
# folium==0.14.0
# fonttools==4.38.0
# frozenlist==1.4.0
# fsspec==2023.10.0
# funcy==2.0
# furl==2.1.0
# future==0.18.2
# fuzzywuzzy==0.18.0
# gast==0.4.0
# gensim==4.3.2
# geographiclib==2.0
# geojson==3.0.1
# geojsoncontour==0.4.0
# geopandas==0.13.2
# geopy==2.3.0
# gitdb==4.0.11
# GitPython==3.1.40
# google-auth==2.16.2
# google-auth-oauthlib==0.4.6
# google-pasta==0.2.0
# gower==0.1.2
# grandalf==0.8
# greenlet==3.0.1
# grpcio==1.34.1
# gsid-utils==0.1
# gto==1.5.0
# h5py==3.1.0
# htmlmin==0.1.12
# huggingface-hub==0.12.0
# hydra-core==1.3.2
# idna==3.4
# ImageHash==4.3.1
# imbalanced-learn==0.10.1
# imblearn==0.0
# importlib-metadata==6.8.0
# inflect==0.2.5
# inflection==0.5.1
# iniconfig==1.1.1
# ipykernel==6.16.1
# ipython==8.5.0
# ipython-genutils==0.2.0
# ipywidgets==8.0.2
# iterative-telemetry==0.0.8
# itsdangerous==2.1.2
# itypes==1.2.0
# jax==0.4.10
# jedi==0.18.1
# jellyfish==0.8.2
# Jinja2==3.1.2
# jmespath==0.10.0
# joblib==1.3.2
# jsii==1.51.0
# json5==0.9.10
# jsonschema==4.16.0
# jupyter==1.0.0
# jupyter-console==6.4.4
# jupyter-core==4.11.1
# jupyter-server==1.21.0
# jupyter_client==7.4.3
# jupyterlab==3.4.8
# jupyterlab-pygments==0.2.2
# jupyterlab-widgets==3.0.3
# jupyterlab_server==2.16.1
# Keras==2.4.3
# keras-nightly==2.5.0.dev2021032900
# Keras-Preprocessing==1.1.2
# kiwisolver==1.4.4
# kneed==0.8.5
# kombu==5.3.2
# langcodes==3.3.0
# levenshtein==0.12.0
# libclang==15.0.6.1
# lightgbm==3.3.5
# livelossplot==0.5.5
# lml==0.1.0
# lofo-importance==0.3.2
# Mako==1.2.4
# mando==0.6.4
# Markdown==3.4.1
# markdown-it-py==3.0.0
# MarkupSafe==2.1.3
# marshmallow==3.10.0
# matplotlib==3.6.3
# matplotlib-inline==0.1.6
# mdurl==0.1.2
# missingno==0.5.1
# mistune==2.0.4
# ml-dtypes==0.1.0
# mlflow==2.8.0
# mock==4.0.3
# more-itertools==8.8.0
# moto==2.0.8
# MouseInfo==0.1.3
# multidict==6.0.4
# multimethod==1.9
# murmurhash==1.0.9
# mysql-connector-python==8.0.31
# nbclassic==0.4.5
# nbclient==0.7.0
# nbconvert==7.2.2
# nbformat==5.6.0
# nbstripout==0.6.0
# nest-asyncio==1.5.8
# networkx==2.8.7
# nltk==3.8.1
# notebook==6.5.1
# notebook-as-pdf==0.5.0
# notebook_shim==0.2.0
# numexpr==2.8.5
# numpy==1.22.4
# oauthlib==3.1.0
# omegaconf==2.3.0
# opencv-python==4.5.4.60
# openpyxl==3.1.2
# opt-einsum==3.3.0
# orderedmultidict==1.0.1
# orjson==3.9.9
# osmnx==1.6.0
# packaging==23.2
# paho-mqtt==1.6.1
# pandas==2.1.0
# pandas-profiling==3.6.6
# pandocfilters==1.5.0
# parso==0.8.3
# pathlib==1.0.1
# pathspec==0.11.2
# pathy==0.10.1
# patsy==0.5.3
# pca==2.0.4
# pdf417decoder==1.0.8
# phik==0.12.2
# pickleshare==0.7.5
# Pillow==10.0.0
# platformdirs==3.11.0
# plotly==5.18.0
# pluggy==0.13.1
# preshed==3.0.8
# progressbar2==4.2.0
# prometheus-client==0.15.0
# prompt-toolkit==3.0.39
# protobuf==3.20.3
# psutil==5.9.4
# publication==0.0.3
# PuLP==2.7.0
# pure-eval==0.2.2
# py==1.10.0
# py4j==0.10.9.5
# pyarrow==11.0.0
# pyasn1==0.4.8
# pyasn1-modules==0.2.8
# PyAutoGUI==0.9.53
# pycparser==2.20
# pydantic==1.10.12
# pydantic_core==2.6.3
# pydash==5.1.0
# pydot==1.4.2
# pyee==8.2.2
# pyexcel==0.6.6
# pyexcel-io==0.6.4
# pyexcel-xlsx==0.6.0
# pygam==0.8.0
# pygeos==0.14
# PyGetWindow==0.0.9
# pygit2==1.13.1
# Pygments==2.13.0
# pygtrie==2.5.0
# PyJWT==2.0.1
# pyLDAvis==3.3.1
# PyMsgBox==1.0.9
# pyparsing==2.4.7
# PyPDF2==2.9.0
# pyperclip==1.8.2
# pyppeteer==1.0.2
# pyproj==3.6.0
# PyRect==0.1.4
# pyrobuf==0.9.3
# pyrosm==0.6.1
# pyrsistent==0.18.1
# PyScreeze==0.1.28
# pyspark==3.2.2
# pyspark-dist-explore==0.1.8
# pytest==6.2.4
# pytest-cov==2.12.1
# pytest-mock==3.6.1
# python-dateutil==2.8.2
# python-dotenv==0.15.0
# python-jose==3.2.0
# python-rapidjson==1.11
# python-utils==3.5.2
# python3-openid==3.2.0
# pytweening==1.0.4
# pytz==2021.1
# PyWavelets==1.4.1
# pywhatkit==5.2
# pywin32==304
# pywinpty==2.0.8
# PyYAML==5.4.1
# pyzmq==24.0.1
# qtconsole==5.3.2
# QtPy==2.2.1
# querystring-parser==1.2.4
# radon==5.1.0
# regex==2023.5.5
# requests==2.31.0
# requests-oauthlib==1.3.0
# responses==0.13.3
# retrying==1.3.4
# rich==13.6.0
# rsa==4.7.2
# ruamel.yaml==0.18.2
# ruamel.yaml.clib==0.2.8
# s3transfer==0.4.2
# scatterd==1.3.6
# scikeras==0.10.0
# scikit-learn==1.3.1
# scikit-learn-extra==0.3.0
# scikit-plot==0.3.7
# scipy==1.10.0
# scmrepo==1.4.0
# seaborn==0.12.2
# semver==3.0.2
# Send2Trash==1.8.0
# seqeval==1.2.2
# Shapely==1.8.5
# shortuuid==1.0.11
# shtab==1.6.4
# simplejson==3.17.6
# six==1.16.0
# sklearn==0.0.post2
# sklearn-contrib-py-earth @ file:///C:/Users/dhoyoso/Documents/Maestria%20UNIANDES/Cursos/INTRODUCCI%C3%93N%20AL%20MACHINE%20LEARNING/sklearn_contrib_py_earth-0.1.0-cp39-cp39-win_amd64.whl
# smart-open==6.3.0
# smmap==5.0.1
# sniffio==1.3.0
# social-auth-app-django==4.0.0
# social-auth-core==4.1.0
# soupsieve==2.3.1
# spacy==3.6.1
# spacy-alignments==0.9.0
# spacy-legacy==3.0.12
# spacy-loggers==1.0.4
# spacy-transformers==1.2.1
# SQLAlchemy==2.0.23
# sqlparse==0.4.1
# sqltrie==0.8.0
# srsly==2.4.5
# stack-data==0.5.1
# stanfordcorenlp==3.9.1.1
# stats==0.1.2a0
# statsmodels==0.13.2
# tabulate==0.9.0
# tangled-up-in-unicode==0.2.0
# tenacity==8.2.3
# tensorboard==2.11.2
# tensorboard-data-server==0.6.1
# tensorboard-plugin-wit==1.8.1
# tensorflow==2.5.0
# tensorflow-estimator==2.5.0
# tensorflow-intel==2.12.0
# tensorflow-io-gcs-filesystem==0.31.0
# termcolor==1.1.0
# terminado==0.16.0
# texttable==1.6.3
# thinc==8.1.12
# thinc-gpu-ops==0.0.4
# threadpoolctl==3.2.0
# tinycss2==1.2.1
# tokenizers==0.13.2
# toml==0.10.2
# tomli==2.0.1
# tomlkit==0.12.1
# torch==1.11.0+cu113
# torchaudio==0.11.0+cu113
# torchvision==0.12.0+cu113
# tornado==6.2
# tqdm==4.66.1
# traitlets==5.4.0
# transformers==4.26.0
# typeguard==2.13.3
# typer==0.7.0
# typing_extensions==4.8.0
# tzdata==2023.3
# unicodecsv==0.14.1
# Unidecode==1.3.6
# uritemplate==3.0.1
# urllib3==2.0.7
# vine==5.0.0
# virtualenv==20.4.2
# visions==0.7.5
# voluptuous==0.13.1
# waitress==2.1.2
# wasabi==1.1.1
# wcwidth==0.2.5
# webencodings==0.5.1
# websocket-client==1.4.1
# websockets==10.3
# Werkzeug==3.0.1
# whitenoise==5.2.0
# widgetsnbextension==4.0.3
# wikipedia==1.4.0
# wordcloud==1.9.2
# wrapt==1.12.1
# xarray==2023.8.0
# xgboost==1.7.4
# xmltodict==0.12.0
# xyzservices==2023.2.0
# yarl==1.9.2
# ydata-profiling==4.5.1
# zc.lockfile==3.0.post1
# zipp==3.17.0
# WARNING: Ignoring invalid distribution -illow (c:\users\dhoyoso\appdata\local\programs\python\python39\lib\site-packages)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import ConfusionMatrixDisplay
#from ydata_profiling import ProfileReport
import joblib
plt.style.use("fivethirtyeight")
# %matplotlib inline

# %% [markdown]
# ## Parte 2 - Comprensión de los datos

# %%
# Cargar los datos del clima 
df_clima=pd.read_csv('Weather Dataset.csv') 
#Muestra las 10 primeras filas del dataset
df_clima.head(10)
# Out:
# C:\Users\dhoyoso\AppData\Local\Temp\ipykernel_9896\2199647736.py:2: DtypeWarning: Columns (7,16) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_clima=pd.read_csv('Weather Dataset.csv')
#    AirportID  Year  Month  Day  Time  TimeZone          SkyCondition  \
# 0      14843  2013      4    1    56        -4  FEW018 SCT044 BKN070
# 1      14843  2013      4    1   156        -4         FEW037 SCT070
# 2      14843  2013      4    1   256        -4         FEW037 SCT070
# 3      14843  2013      4    1   356        -4         FEW025 SCT070
# 4      14843  2013      4    1   456        -4                FEW025
# 5      14843  2013      4    1   556        -4         FEW025 SCT080
# 6      14843  2013      4    1   656        -4         FEW028 BKN080
# 7      14843  2013      4    1   756        -4         FEW028 BKN080
# 8      14843  2013      4    1   856        -4         FEW030 BKN080
# 9      14843  2013      4    1   956        -4         SCT035 BKN090
#
#   Visibility WeatherType DryBulbFarenheit  ... WindSpeed WindDirection  \
# 0      10.00         -RA               76  ...        13           080
# 1      10.00                           76  ...        10           090
# 2      10.00                           76  ...         9           100
# 3      10.00                           76  ...         9           100
# 4      10.00                           76  ...         7           110
# 5      10.00                           76  ...         7           100
# 6      10.00                           77  ...         9           110
# 7      10.00                           79  ...        13           100
# 8      10.00                           82  ...        14           100
# 9      10.00                           83  ...        16           090
#
#   ValueForWindCharacter StationPressure PressureTendency PressureChange  \
# 0                                 30.06
# 1                                 30.05                6            017
# 2                                 30.03
# 3                                 30.02
# 4                                 30.03                5            004
# 5                                 30.04
# 6                                 30.07
# 7                                 30.09                3            020
# 8                    21           30.11
# 9                    23           30.11
#
#   SeaLevelPressure RecordType HourlyPrecip Altimeter
# 0            30.06         AA            T     30.07
# 1            30.05         AA                  30.06
# 2            30.03         AA                  30.04
# 3            30.03         AA                  30.03
# 4            30.04         AA                  30.04
# 5            30.05         AA                  30.05
# 6            30.07         AA                  30.08
# 7            30.10         AA                  30.10
# 8            30.11         AA                  30.12
# 9            30.12         AA                  30.12
#
# [10 rows x 26 columns]

# %% [markdown]
# ##### Diccionario de datos
# - Year, Month, Day, Time, TimeZone – Fecha y hora del vuelo
# - AirportID – Número de Identificación para un único aeropuerto
# - Un set de variables metereológicas específicas: SkyCondition, Visibility, WeatherType, DryBulbFarenheit, DryBulbCelsius, StationPressure,
# PressureTendency, PressureChange, SeaLevelPressure, RecordType, HourlyPrecip, Altimeter,….

# %%
#Cargar los datos de los vuelos 
df_vuelos = pd.read_csv('Flight Delays Data.csv')
df_vuelos.head(10)
# Out:
#    Year  Month  DayofMonth  DayOfWeek Carrier  OriginAirportID  DestAirportID  \
# 0  2013      4          19          5      DL            11433          13303
# 1  2013      4          19          5      DL            14869          12478
# 2  2013      4          19          5      DL            14057          14869
# 3  2013      4          19          5      DL            15016          11433
# 4  2013      4          19          5      DL            11193          12892
# 5  2013      4          19          5      DL            10397          15016
# 6  2013      4          19          5      DL            15016          10397
# 7  2013      4          19          5      DL            10397          14869
# 8  2013      4          19          5      DL            10397          10423
# 9  2013      4          19          5      DL            11278          10397
#
#    CRSDepTime  DepDelay  DepDel15  CRSArrTime  ArrDelay  ArrDel15  Cancelled
# 0         837      -3.0       0.0        1138       1.0       0.0        0.0
# 1        1705       0.0       0.0        2336      -8.0       0.0        0.0
# 2         600      -4.0       0.0         851     -15.0       0.0        0.0
# 3        1630      28.0       1.0        1903      24.0       1.0        0.0
# 4        1615      -6.0       0.0        1805     -11.0       0.0        0.0
# 5        1726      -1.0       0.0        1818     -19.0       0.0        0.0
# 6        1900       0.0       0.0        2133      -1.0       0.0        0.0
# 7        2145      15.0       1.0        2356      24.0       1.0        0.0
# 8        2157      33.0       1.0        2333      34.0       1.0        0.0
# 9        1900     323.0       1.0        2055     322.0       1.0        0.0

# %% [markdown]
# ##### Diccionario de datos
# - Información del vuelo (Calendario): Año – Mes – Día
# - Carrier- Código usado comunmente para identificar una aerolínea
# - Aeropuerto Origen – Destino – Codigo de identificación del aeropuerto
# - CRS DepTme - CRSArr Time Los tiempos CRS de salida y llegada, usando hora local (hhmm)
# - Dep Delay- Arr delay Diferencia en minutos entre el tiempos de salida y llegada programados y los actuales.
# - DepDel15 - ArrDel15 Un valor boleano que indica si los tiempos de salida o llegada tienen un retraso de más de 15 minutos.
# - Cancelled - Un valor booleano que indica si el vuelo fue cancelado (1=Vuelo cancelado)

# %%
#Información sobre el set de datos
df_clima.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 406516 entries, 0 to 406515
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   AirportID              406516 non-null  int64
#  1   Year                   406516 non-null  int64
#  2   Month                  406516 non-null  int64
#  3   Day                    406516 non-null  int64
#  4   Time                   406516 non-null  int64
#  5   TimeZone               406516 non-null  int64
#  6   SkyCondition           406516 non-null  object
#  7   Visibility             406516 non-null  object
#  8   WeatherType            406516 non-null  object
#  9   DryBulbFarenheit       406516 non-null  object
#  10  DryBulbCelsius         406516 non-null  object
#  11  WetBulbFarenheit       406516 non-null  object
#  12  WetBulbCelsius         406516 non-null  object
#  13  DewPointFarenheit      406516 non-null  object
#  14  DewPointCelsius        406516 non-null  object
#  15  RelativeHumidity       406516 non-null  object
#  16  WindSpeed              406516 non-null  object
#  17  WindDirection          406516 non-null  object
#  18  ValueForWindCharacter  406516 non-null  object
#  19  StationPressure        406516 non-null  object
#  20  PressureTendency       406516 non-null  object
#  21  PressureChange         406516 non-null  object
#  22  SeaLevelPressure       406516 non-null  object
#  23  RecordType             406516 non-null  object
#  24  HourlyPrecip           406516 non-null  object
#  25  Altimeter              406516 non-null  object
# dtypes: int64(6), object(20)
# memory usage: 80.6+ MB

# %%
#Información sobre el set de datos
df_vuelos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1006472 entries, 0 to 1006471
# Data columns (total 14 columns):
#  #   Column           Non-Null Count    Dtype
# ---  ------           --------------    -----
#  0   Year             1006472 non-null  int64
#  1   Month            1006472 non-null  int64
#  2   DayofMonth       1006472 non-null  int64
#  3   DayOfWeek        1006472 non-null  int64
#  4   Carrier          1006472 non-null  object
#  5   OriginAirportID  1006472 non-null  int64
#  6   DestAirportID    1006472 non-null  int64
#  7   CRSDepTime       1006472 non-null  int64
#  8   DepDelay         994663 non-null   float64
#  9   DepDel15         994663 non-null   float64
#  10  CRSArrTime       1006472 non-null  int64
#  11  ArrDelay         993999 non-null   float64
#  12  ArrDel15         1006472 non-null  float64
#  13  Cancelled        1006472 non-null  float64
# dtypes: float64(5), int64(8), object(1)
# memory usage: 107.5+ MB

# %% [markdown]
# ## Parte 3 Preparación de datos

# %% [markdown]
# ### 3.1 Transformación de variables

# %% [markdown]
# ¿ Qué variables de los datasets no están en el tipo correcto? ¿Qué podemos hacer con los ids?

# %%
# Vamos primero a transformar los tipos de datos de las variables del dataset de clima
# Transforma una variable numérica a una categórica (Tipo String)
df_clima['AirportID'] = df_clima['AirportID'].astype(str)

#Transforma el tipo de datos a variables numéricas (enteros y decimales)
df_clima['Visibility'] = pd.to_numeric(df_clima['Visibility'], errors='coerce')
df_clima['DryBulbFarenheit'] = pd.to_numeric(df_clima['DryBulbFarenheit'], errors='coerce')
df_clima['DryBulbCelsius'] = pd.to_numeric(df_clima['DryBulbCelsius'], errors='coerce')
df_clima['WetBulbFarenheit'] = pd.to_numeric(df_clima['WetBulbFarenheit'], errors='coerce')
df_clima['WetBulbCelsius'] = pd.to_numeric(df_clima['WetBulbCelsius'], errors='coerce')
df_clima['DewPointFarenheit'] = pd.to_numeric(df_clima['DewPointFarenheit'], errors='coerce')
df_clima['DewPointCelsius'] = pd.to_numeric(df_clima['DewPointCelsius'], errors='coerce')
df_clima['RelativeHumidity'] = pd.to_numeric(df_clima['RelativeHumidity'], errors='coerce')
df_clima['WindSpeed'] = pd.to_numeric(df_clima['WindSpeed'], errors='coerce')
df_clima['WindDirection'] = pd.to_numeric(df_clima['WindDirection'], errors='coerce')
df_clima['ValueForWindCharacter'] = pd.to_numeric(df_clima['ValueForWindCharacter'], errors='coerce')
df_clima['StationPressure'] = pd.to_numeric(df_clima['StationPressure'], errors='coerce')
df_clima['PressureTendency'] = pd.to_numeric(df_clima['PressureTendency'], errors='coerce')
df_clima['PressureChange'] = pd.to_numeric(df_clima['PressureChange'], errors='coerce')
df_clima['SeaLevelPressure'] = pd.to_numeric(df_clima['SeaLevelPressure'], errors='coerce')
df_clima['Altimeter'] = pd.to_numeric(df_clima['Altimeter'], errors='coerce')

# %%
df_clima.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 406516 entries, 0 to 406515
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   AirportID              406516 non-null  object
#  1   Year                   406516 non-null  int64
#  2   Month                  406516 non-null  int64
#  3   Day                    406516 non-null  int64
#  4   Time                   406516 non-null  int64
#  5   TimeZone               406516 non-null  int64
#  6   SkyCondition           406516 non-null  object
#  7   Visibility             406408 non-null  float64
#  8   WeatherType            406516 non-null  object
#  9   DryBulbFarenheit       406227 non-null  float64
#  10  DryBulbCelsius         406227 non-null  float64
#  11  WetBulbFarenheit       405019 non-null  float64
#  12  WetBulbCelsius         405019 non-null  float64
#  13  DewPointFarenheit      406135 non-null  float64
#  14  DewPointCelsius        406135 non-null  float64
#  15  RelativeHumidity       405019 non-null  float64
#  16  WindSpeed              406367 non-null  float64
#  17  WindDirection          395063 non-null  float64
#  18  ValueForWindCharacter  49519 non-null   float64
#  19  StationPressure        405294 non-null  float64
#  20  PressureTendency       15992 non-null   float64
#  21  PressureChange         15992 non-null   float64
#  22  SeaLevelPressure       333616 non-null  float64
#  23  RecordType             406516 non-null  object
#  24  HourlyPrecip           406516 non-null  object
#  25  Altimeter              406405 non-null  float64
# dtypes: float64(16), int64(5), object(5)
# memory usage: 80.6+ MB

# %%
# Ahora vamos a transformar los tipos de datos de las variables del dataset de vuelos

#Transformamos los números de identificación a tipo string
df_vuelos['OriginAirportID'] = df_vuelos['OriginAirportID'].astype(str)
df_vuelos['DestAirportID'] = df_vuelos['DestAirportID'].astype(str)

# Transformamos las variables a tipo booleano cuando el 1 o 0 indican verdadero o falso
df_vuelos['DepDel15'] = df_vuelos['DepDel15'].astype(bool)
df_vuelos['ArrDel15'] = df_vuelos['ArrDel15'].astype(bool)
df_vuelos['Cancelled'] = df_vuelos['Cancelled'].astype(bool)

# %%
df_vuelos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1006472 entries, 0 to 1006471
# Data columns (total 14 columns):
#  #   Column           Non-Null Count    Dtype
# ---  ------           --------------    -----
#  0   Year             1006472 non-null  int64
#  1   Month            1006472 non-null  int64
#  2   DayofMonth       1006472 non-null  int64
#  3   DayOfWeek        1006472 non-null  int64
#  4   Carrier          1006472 non-null  object
#  5   OriginAirportID  1006472 non-null  object
#  6   DestAirportID    1006472 non-null  object
#  7   CRSDepTime       1006472 non-null  int64
#  8   DepDelay         994663 non-null   float64
#  9   DepDel15         1006472 non-null  bool
#  10  CRSArrTime       1006472 non-null  int64
#  11  ArrDelay         993999 non-null   float64
#  12  ArrDel15         1006472 non-null  bool
#  13  Cancelled        1006472 non-null  bool
# dtypes: bool(3), float64(2), int64(6), object(3)
# memory usage: 87.3+ MB

# %% [markdown]
# ¿ Ahora qué hacemos con las variables que nos inidican fechas u horas? Es importante que estas variables sean consistentes entre los 2 datasets para garantizar que se puede integrar la información de manera consistente

# %%
# Como las horas de las mediciones metereológicas no son exactamente las mismas 
#a las horas de despegue de los vuelos haremos una aproximación a la hora más cercana

# Tranformamos la variable del data frame de vuelos
df_vuelos['CRSDepTime'] = df_vuelos['CRSDepTime'].apply(lambda x: x/100)
df_vuelos['CRSDepTime'] = df_vuelos['CRSDepTime'].round(0)
df_vuelos['CRSDepTime']
# Out:
# 0           8.0
# 1          17.0
# 2           6.0
# 3          16.0
# 4          16.0
#            ...
# 1006467     8.0
# 1006468    18.0
# 1006469    22.0
# 1006470    12.0
# 1006471    10.0
# Name: CRSDepTime, Length: 1006472, dtype: float64

# %%
# Realice la misma operación para la variable del data frame de clima
df_clima['Time'] = df_clima['Time'].apply(lambda x: x/100)
df_clima['Time'] = df_clima['Time'].round(0)
df_clima['Time']
# Out:
# 0          1.0
# 1          2.0
# 2          3.0
# 3          4.0
# 4          5.0
#           ...
# 406511    22.0
# 406512    22.0
# 406513    23.0
# 406514    23.0
# 406515    24.0
# Name: Time, Length: 406516, dtype: float64

# %% [markdown]
# ### 3.2 Tratamiento de valores faltanes

# %%
# Identificamos la cantidad de valores nulos en cada uno de los datasets
df_vuelos.isnull().sum().divide(len(df_vuelos)).multiply(100)
# Out:
# Year               0.000000
# Month              0.000000
# DayofMonth         0.000000
# DayOfWeek          0.000000
# Carrier            0.000000
# OriginAirportID    0.000000
# DestAirportID      0.000000
# CRSDepTime         0.000000
# DepDelay           1.173306
# DepDel15           0.000000
# CRSArrTime         0.000000
# ArrDelay           1.239279
# ArrDel15           0.000000
# Cancelled          0.000000
# dtype: float64

# %% [markdown]
# ¿Qué estrategia para el tratamiento de valores faltantes escaogería para cada una de las variables?

# %%
# Elimanos las observaciones que tienen nulos en la variables DepDelay y ArrDelay 
# dado que esta es la variable y el % de faltantes es bajo

df_vuelos.dropna(subset=['DepDelay'], inplace=True)
df_vuelos.dropna(subset=['ArrDelay'], inplace=True)
df_vuelos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 993999 entries, 0 to 1006471
# Data columns (total 14 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   Year             993999 non-null  int64
#  1   Month            993999 non-null  int64
#  2   DayofMonth       993999 non-null  int64
#  3   DayOfWeek        993999 non-null  int64
#  4   Carrier          993999 non-null  object
#  5   OriginAirportID  993999 non-null  object
#  6   DestAirportID    993999 non-null  object
#  7   CRSDepTime       993999 non-null  float64
#  8   DepDelay         993999 non-null  float64
#  9   DepDel15         993999 non-null  bool
#  10  CRSArrTime       993999 non-null  int64
#  11  ArrDelay         993999 non-null  float64
#  12  ArrDel15         993999 non-null  bool
#  13  Cancelled        993999 non-null  bool
# dtypes: bool(3), float64(3), int64(5), object(3)
# memory usage: 93.8+ MB

# %%
# Identificamos la cantidad de valores nulos en cada uno de los datasets
# Calculamos el % de faltantes en cada una de las variables
df_clima.isnull().sum().divide(len(df_clima)).multiply(100)
# Out:
# AirportID                 0.000000
# Year                      0.000000
# Month                     0.000000
# Day                       0.000000
# Time                      0.000000
# TimeZone                  0.000000
# SkyCondition              0.000000
# Visibility                0.026567
# WeatherType               0.000000
# DryBulbFarenheit          0.071092
# DryBulbCelsius            0.071092
# WetBulbFarenheit          0.368251
# WetBulbCelsius            0.368251
# DewPointFarenheit         0.093723
# DewPointCelsius           0.093723
# RelativeHumidity          0.368251
# WindSpeed                 0.036653
# WindDirection             2.817355
# ValueForWindCharacter    87.818684
# StationPressure           0.300603
# PressureTendency         96.066083
# PressureChange           96.066083
# SeaLevelPressure         17.932873
# RecordType                0.000000
# HourlyPrecip              0.000000
# Altimeter                 0.027305
# dtype: float64

# %% [markdown]
# ¿Qué estrategia para el tratamiento de valores faltantes escaogería para cada una de las variables?

# %%
# Eliminamos las variables que tienen un alto % de faltantes
df_clima =df_clima.drop(['ValueForWindCharacter', 'PressureTendency','PressureChange','SeaLevelPressure'], axis=1)

#Eliminamos las obersvaciones que tienen alguna otro valor faltante dado que es un pequeño %
df_clima = df_clima.dropna(how='any',axis=0) 

df_clima.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 393636 entries, 0 to 406515
# Data columns (total 22 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   AirportID          393636 non-null  object
#  1   Year               393636 non-null  int64
#  2   Month              393636 non-null  int64
#  3   Day                393636 non-null  int64
#  4   Time               393636 non-null  float64
#  5   TimeZone           393636 non-null  int64
#  6   SkyCondition       393636 non-null  object
#  7   Visibility         393636 non-null  float64
#  8   WeatherType        393636 non-null  object
#  9   DryBulbFarenheit   393636 non-null  float64
#  10  DryBulbCelsius     393636 non-null  float64
#  11  WetBulbFarenheit   393636 non-null  float64
#  12  WetBulbCelsius     393636 non-null  float64
#  13  DewPointFarenheit  393636 non-null  float64
#  14  DewPointCelsius    393636 non-null  float64
#  15  RelativeHumidity   393636 non-null  float64
#  16  WindSpeed          393636 non-null  float64
#  17  WindDirection      393636 non-null  float64
#  18  StationPressure    393636 non-null  float64
#  19  RecordType         393636 non-null  object
#  20  HourlyPrecip       393636 non-null  object
#  21  Altimeter          393636 non-null  float64
# dtypes: float64(13), int64(4), object(5)
# memory usage: 69.1+ MB

# %% [markdown]
# ### Parte 3.3 - Integración de los datos

# %% [markdown]
# ¿Cuáles son variables presentes en ambos conjunstos de datos?¿ De estas, qué variables debemos coincidir entre el conjunto de datos de vuelos y el de clima para garantizar una integración de datos consistente?

# %%
# Integramos las 2 bases de datos en un único conjunto de datos
merged_data = df_vuelos.merge(df_clima, left_on=['Month','DayofMonth','OriginAirportID','CRSDepTime'], 
                                right_on=['Month','Day','AirportID','Time'], how='inner')
merged_data.head()
# Out:
#    Year_x  Month  DayofMonth  DayOfWeek Carrier OriginAirportID DestAirportID  \
# 0    2013      4          19          5      DL           11433         13303
# 1    2013      4          19          5      DL           11433         13303
# 2    2013      4          19          5      DL           11433         11298
# 3    2013      4          19          5      DL           11433         11298
# 4    2013      4          19          5      DL           11433         11292
#
#    CRSDepTime  DepDelay  DepDel15  ...  WetBulbCelsius  DewPointFarenheit  \
# 0         8.0      -3.0     False  ...             6.9               44.0
# 1         8.0      -3.0     False  ...             6.6               43.0
# 2         8.0      22.0      True  ...             6.9               44.0
# 3         8.0      22.0      True  ...             6.6               43.0
# 4         8.0      -5.0     False  ...             6.9               44.0
#
#    DewPointCelsius  RelativeHumidity WindSpeed  WindDirection  \
# 0              6.7              96.0      16.0          220.0
# 1              6.0              93.0      21.0          220.0
# 2              6.7              96.0      16.0          220.0
# 3              6.0              93.0      21.0          220.0
# 4              6.7              96.0      16.0          220.0
#
#    StationPressure  RecordType  HourlyPrecip Altimeter
# 0            28.75          AA             T     29.45
# 1            28.77          SP                   29.47
# 2            28.75          AA             T     29.45
# 3            28.77          SP                   29.47
# 4            28.75          AA             T     29.45
#
# [5 rows x 35 columns]

# %%
merged_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1029807 entries, 0 to 1029806
# Data columns (total 35 columns):
#  #   Column             Non-Null Count    Dtype
# ---  ------             --------------    -----
#  0   Year_x             1029807 non-null  int64
#  1   Month              1029807 non-null  int64
#  2   DayofMonth         1029807 non-null  int64
#  3   DayOfWeek          1029807 non-null  int64
#  4   Carrier            1029807 non-null  object
#  5   OriginAirportID    1029807 non-null  object
#  6   DestAirportID      1029807 non-null  object
#  7   CRSDepTime         1029807 non-null  float64
#  8   DepDelay           1029807 non-null  float64
#  9   DepDel15           1029807 non-null  bool
#  10  CRSArrTime         1029807 non-null  int64
#  11  ArrDelay           1029807 non-null  float64
#  12  ArrDel15           1029807 non-null  bool
#  13  Cancelled          1029807 non-null  bool
#  14  AirportID          1029807 non-null  object
#  15  Year_y             1029807 non-null  int64
#  16  Day                1029807 non-null  int64
#  17  Time               1029807 non-null  float64
#  18  TimeZone           1029807 non-null  int64
#  19  SkyCondition       1029807 non-null  object
#  20  Visibility         1029807 non-null  float64
#  21  WeatherType        1029807 non-null  object
#  22  DryBulbFarenheit   1029807 non-null  float64
#  23  DryBulbCelsius     1029807 non-null  float64
#  24  WetBulbFarenheit   1029807 non-null  float64
#  25  WetBulbCelsius     1029807 non-null  float64
#  26  DewPointFarenheit  1029807 non-null  float64
#  27  DewPointCelsius    1029807 non-null  float64
#  28  RelativeHumidity   1029807 non-null  float64
#  29  WindSpeed          1029807 non-null  float64
#  30  WindDirection      1029807 non-null  float64
#  31  StationPressure    1029807 non-null  float64
#  32  RecordType         1029807 non-null  object
#  33  HourlyPrecip       1029807 non-null  object
#  34  Altimeter          1029807 non-null  float64
# dtypes: bool(3), float64(16), int64(8), object(8)
# memory usage: 254.4+ MB

# %% [markdown]
# ### 3.4 Selección de variables

# %% [markdown]
# ¿Qué variables quedaron duplicadas al hacer la integración de las bases de datos?
# ¿Qué variables están proporcionando la misma información?

# %%
#Primero eliminamos todas las variables duplicadas
merged_data =merged_data.drop(['Year_x', 'DayofMonth','OriginAirportID','Time'], axis=1)

# Ahora eliminamos variables que nos están proporcionando la misma información (e.g., Farenheit y Celsius)
merged_data =merged_data.drop(['DryBulbFarenheit', 'WetBulbFarenheit','DewPointFarenheit',
                               'DepDelay','ArrDelay'], axis=1)

# %% [markdown]
# Ahora pensemos cuáles de las variables que tenemos en nuestro dataset no nos proporcionan información relevante para hacer la predicción o son una fuga de información (esto quiere decir que son variables que no tendremos registradas al momento de hacer la predicción para nuevos datos)

# %%
#Eliminamos las variables que no proprocionan información útil
merged_data =merged_data.drop(['Year_y','TimeZone'], axis=1) #'DestAirportID','AirportID'

# Ahora eliminamos variables que son fuga de información
merged_data =merged_data.drop(['ArrDel15','Cancelled','CRSArrTime','CRSDepTime'], axis=1)

#Eliminamos variables que tienen el mismo valorr en todo el conjunto
merged_data =merged_data.drop(['Carrier','SkyCondition','WeatherType','HourlyPrecip'], axis=1)
merged_data.head()
# Out:
#    Month  DayOfWeek DestAirportID  DepDel15 AirportID  Day  Visibility  \
# 0      4          5         13303     False     11433   19        10.0
# 1      4          5         13303     False     11433   19        10.0
# 2      4          5         11298      True     11433   19        10.0
# 3      4          5         11298      True     11433   19        10.0
# 4      4          5         11292     False     11433   19        10.0
#
#    DryBulbCelsius  WetBulbCelsius  DewPointCelsius  RelativeHumidity  \
# 0             7.2             6.9              6.7              96.0
# 1             7.0             6.6              6.0              93.0
# 2             7.2             6.9              6.7              96.0
# 3             7.0             6.6              6.0              93.0
# 4             7.2             6.9              6.7              96.0
#
#    WindSpeed  WindDirection  StationPressure RecordType  Altimeter
# 0       16.0          220.0            28.75         AA      29.45
# 1       21.0          220.0            28.77         SP      29.47
# 2       16.0          220.0            28.75         AA      29.45
# 3       21.0          220.0            28.77         SP      29.47
# 4       16.0          220.0            28.75         AA      29.45

# %%
Record = pd.get_dummies(merged_data['RecordType'])
merged_data = pd.concat([merged_data, Record], axis = 1)
merged_data.head()
# Out:
#    Month  DayOfWeek DestAirportID  DepDel15 AirportID  Day  Visibility  \
# 0      4          5         13303     False     11433   19        10.0
# 1      4          5         13303     False     11433   19        10.0
# 2      4          5         11298      True     11433   19        10.0
# 3      4          5         11298      True     11433   19        10.0
# 4      4          5         11292     False     11433   19        10.0
#
#    DryBulbCelsius  WetBulbCelsius  DewPointCelsius  RelativeHumidity  \
# 0             7.2             6.9              6.7              96.0
# 1             7.0             6.6              6.0              93.0
# 2             7.2             6.9              6.7              96.0
# 3             7.0             6.6              6.0              93.0
# 4             7.2             6.9              6.7              96.0
#
#    WindSpeed  WindDirection  StationPressure RecordType  Altimeter     AA  \
# 0       16.0          220.0            28.75         AA      29.45   True
# 1       21.0          220.0            28.77         SP      29.47  False
# 2       16.0          220.0            28.75         AA      29.45   True
# 3       21.0          220.0            28.77         SP      29.47  False
# 4       16.0          220.0            28.75         AA      29.45   True
#
#       SP  SY-MT
# 0  False  False
# 1   True  False
# 2  False  False
# 3   True  False
# 4  False  False

# %%
merged_data.drop(['RecordType'],axis=1, inplace=True)

# %%
def preprocess_data(data):
    # Realiza el tratamiento de datos
    Record = pd.get_dummies(data['RecordType'])
    data = pd.concat([data, Record], axis=1)
    data.drop(['RecordType'], axis=1, inplace=True)
    
    return data
# merged_data = merged_data.drop(merged_data[(merged_data['Month'] < 6)].index)

# %%
joblib.dump(preprocess_data, 'preprocess_function.pkl')
# Out:
# ['preprocess_function.pkl']

# %%
# merged_data['flight_route'] = merged_data['DestAirportID'].astype(str) + '_' + merged_data['AirportID'].astype(str)
# merged_data = pd.get_dummies(merged_data, columns=['flight_route'])
# merged_data.drop(['DestAirportID','AirportID'],axis=1, inplace=True)
# merged_data.head()

# %%
merged_data.to_csv('merged_data.csv', index=False)

# %% [markdown]
# # Paso 4 Modelado

# %%
#División del dataset en variable objetivo (Y) y variables explicativas (X)
X = merged_data.drop(columns =['DepDel15'],axis=1)
Y = merged_data['DepDel15']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.3)

# %%
y_test.to_csv('y_test.csv', index=False)

# %%
X_test.to_csv('merged_data.csv', index=False)
# Out:
#          Month  DayOfWeek DestAirportID AirportID  Day  Visibility  \
# 570337       5          3         12264     14524    8         0.5
# 787003       5          7         10529     10821   19         7.0
# 450319       5          4         13495     12191   23        10.0
# 218667       4          3         11278     10397   10        10.0
# 545226       5          4         12953     11697   30        10.0
# ...        ...        ...           ...       ...  ...         ...
# 1028858      6          3         11057     15304   26        10.0
# 308339       4          5         11433     13931    5        10.0
# 938786       6          7         14492     12339   23         7.0
# 259650       4          5         11066     13232   12        10.0
# 280604       4          3         11298     11278   10        10.0
#
#          DryBulbCelsius  WetBulbCelsius  DewPointCelsius  RelativeHumidity  \
# 570337             11.7            11.6             11.7             100.0
# 787003             19.0            18.2             18.0              93.0
# 450319             28.9            24.2             22.2              67.0
# 218667             22.8            16.2             11.7              50.0
# 545226             27.3            24.5             23.5              79.0
# ...                 ...             ...              ...               ...
# 1028858            23.9            23.8             23.9             100.0
# 308339             10.0             8.3              6.7              80.0
# 938786             21.7            20.5             20.0              90.0
# 259650              4.0             1.4             -2.0              65.0
# 280604             28.9            18.7             12.2              36.0
#
#          WindSpeed  WindDirection  StationPressure  Altimeter     AA     SP  \
# 570337         0.0            0.0            29.79      29.97   True  False
# 787003         8.0           90.0            29.96      30.13  False   True
# 450319        10.0          160.0            29.96      30.01   True  False
# 218667        11.0          180.0            28.87      29.96   True  False
# 545226        22.0          100.0            30.01      30.02   True  False
# ...            ...            ...              ...        ...    ...    ...
# 1028858        0.0            0.0            30.05      30.06   True  False
# 308339        11.0          360.0            29.87      29.90   True  False
# 938786         9.0          140.0            29.19      30.06   True  False
# 259650        18.0          260.0            29.15      29.81  False   True
# 280604        11.0          190.0            29.75      29.82   True  False
#
#          SY-MT
# 570337   False
# 787003   False
# 450319   False
# 218667   False
# 545226   False
# ...        ...
# 1028858  False
# 308339   False
# 938786   False
# 259650   False
# 280604   False
#
# [308943 rows x 17 columns]

# %%
### Entrenamiento de los modelos

# %%
#Importamos las librerias de sklearn con los diferentes algoritmos que queremos probar
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.model_selection import cross_val_score
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.feature_selection import SelectKBest, f_classif
from sklearn.feature_selection import SelectFromModel
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.naive_bayes import MultinomialNB
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.feature_selection import SelectFromModel

# %% [markdown]
# ### MODELADO

# %%
# Crea un modelo Gradient Boosting
model = GradientBoostingClassifier(
    n_estimators=100,
    max_depth=3,
    max_features='sqrt',
    loss='exponential',
    learning_rate=0.05,
    random_state=42
)

# Entrena el modelo en el conjunto de datos equilibrado
model.fit(X_train, y_train)

# Realiza predicciones en el conjunto de prueba
y_pred = model.predict(X_test)

# Evalúa el modelo en el conjunto de prueba
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

# Imprime las métricas de evaluación
print(f'Accuracy: {accuracy:.2f}')
print(f'Precision: {precision:.2f}')
print(f'Recall: {recall:.2f}')
print(f'F1 Score: {f1:.2f}')
# Out:
# Accuracy: 0.79
# Precision: 0.79
# Recall: 0.01
# F1 Score: 0.03

# %%
# Guardas el modelo en un archivo .pkl
joblib.dump(model, 'modelo_entrenado.pkl')
# Out:
# ['modelo_entrenado.pkl']
